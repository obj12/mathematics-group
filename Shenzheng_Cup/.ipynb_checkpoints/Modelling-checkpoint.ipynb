# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import scipy.optimize as op
plt.rcParams['font.sans-serif']=['SimHei']

# %%
all_data=pd.read_excel("SpeedVideoDataforModeling.xlsx")

# %%
data.columns
# Out:
# Index(['ID', '初始缓冲峰值速率(kbps)', 'E2E RTT(ms)', '播放阶段平均速率(kbps)', '初始缓冲时延(ms)',
#        '卡顿占比', 'VMOS', '视频全程感知速率(kbps)', '卡顿时长(ms)', '播放时长(ms)', '播放阶段总时长(ms)',
#        '卡顿次数', '视频码率(kbps)', '初始缓冲下载数据量(byte)', '视频质量得分SQuality',
#        '初始缓冲得分SLoading', '卡顿得分Sstalling'],
#       dtype='object')

# %% [raw]
# 1.缓冲时间模型

# %%
data = all_data[all_data.iloc[:,11]==0]#选出非卡顿数据

# %%
#数据清洗，统一单位
MSS=1460*8/1000 #kb or 536
RTT=data['E2E RTT(ms)']
v_max=data['初始缓冲峰值速率(kbps)']
D_0=data['初始缓冲下载数据量(byte)']*8/1000
D_0.name='初始缓冲下载数据量(kb)'
tau=data['初始缓冲时延(ms)']

# %%
def tau_model(tup,n):
    D_0,v_max,RTT,MSS=tup
    Ds=2*(RTT/1000*v_max-MSS)
    s=np.log2((RTT/1000)*v_max/MSS)
    return (D_0-Ds)/(0.75*v_max)*1000+(n+s)*RTT #ms

# %%
#n, cov=op.curve_fit(mu_model,(D_0,Ds,v_max,RTT),mu)#fit

# %%
# 考虑到 n 取值范围为 1-9 整数
tau_expect=tau_model((D_0,v_max,RTT,MSS),9)
tau_expect.name='预期缓冲时延(ms)'

# %%
tau_compare=pd.DataFrame([tau_expect,tau]).transpose()
tau_compare[0:30]
# Out:
#      预期缓冲时延(ms)  初始缓冲时延(ms)
# 0   1120.858182      1108.0
# 1   1064.648133      1095.0
# 2    996.492266      1051.0
# 3   1081.723653      1099.0
# 4   1074.084055      1133.0
# 5   1084.253964      1132.0
# 6   1077.769879      1020.0
# 7   1100.837574      1029.0
# 8   1148.517482      1133.0
# 9   1007.654138       973.0
# 10   994.773396      1006.0
# 11  1016.421759       957.0
# 12   912.791849       933.0
# 13   999.061764      1003.0
# 14  1126.464257      1041.0
# 15  1071.132338      1004.0
# 16  1052.190985      1011.0
# 17  1110.015992      1049.0
# 18  1044.167657      1006.0
# 19  1209.941806      1079.0
# 20  1115.825837      1051.0
# 21   963.018924       948.0
# 22  1064.686145      1055.0
# 23  1077.522258      1028.0
# 24  1128.929391      1040.0
# 25  1067.322950      1016.0
# 26  1027.294016      1137.0
# 27  1166.560442      1146.0
# 28   982.367428      1062.0
# 29  1161.200387      1035.0

# %%
tau_compare.corr()
# Out:
#             预期缓冲时延(ms)  初始缓冲时延(ms)
# 预期缓冲时延(ms)    1.000000    0.878418
# 初始缓冲时延(ms)    0.878418    1.000000

# %%
import matplotlib.patches as mpatches

# %%
_sample=tau_compare.sample(400)
x=_sample.iloc[:,0]
y=_sample.iloc[:,1]
plt.clf()
_g1=plt.figure()
plt.scatter(x,y,color='tab:blue',label='实际数据点')
plt.plot(x,x,color='tab:orange',linewidth=1,linestyle='--',label='预期拟合曲线')
plt.plot(x,np.polyval(np.polyfit(x,y,1),x),color='tab:olive',linewidth=1.5,label='实际拟合曲线')
plt.xlabel('预期缓冲时延(ms)')
plt.ylabel('初始缓冲时延(ms)')
plt.legend(loc='upper right')
_g1.dpi=120
plt.show()

# %% [raw]
# 1.可以看出，预期时延低于实际时延，这是因为高估了理论传输速度。
# 这是由于文献在建模中将离散的时间序列作为连续函数进行积分，从而导致速率偏大。我们在模型的改进中给出了这一模型的修正。
# 2.而且，模型在时延较低时与数据符合较好。
# 这是由于低时延数据通常丢包率p较低，tcp协议过程接近理想过程。
# 而时延增加说明网路状况较差（RTT时间长，丢包率p较高）
# ，丢包的随机性网路的影响增加导致数据出现波动。同时，在实际的TCP传输过程中，丢包还会引起超时重发机制的响应，使得已经减小的发送窗口被重发的丢失数据包占用，从而使网络效率再度降低。文献中通过离散时间Markov模型模拟了相关机制，在此由于其模型过于复杂故不再考虑。

# %% [raw]
# 2.卡顿时间模型

# %%
data.columns
# Out:
# Index(['ID', '初始缓冲峰值速率(kbps)', 'E2E RTT(ms)', '播放阶段平均速率(kbps)', '初始缓冲时延(ms)',
#        '卡顿占比', 'VMOS', '视频全程感知速率(kbps)', '卡顿时长(ms)', '播放时长(ms)', '播放阶段总时长(ms)',
#        '卡顿次数', '视频码率(kbps)', '初始缓冲下载数据量(byte)', '视频质量得分SQuality',
#        '初始缓冲得分SLoading', '卡顿得分Sstalling'],
#       dtype='object')

# %%
data = all_data[all_data.iloc[:,11]!=0]#选出卡顿数据

# %%
MSS=1460*8#bits
RTT=data['E2E RTT(ms)']
t_total=data['播放阶段总时长(ms)']
t_p=data[ '播放时长(ms)']
t_s=data['卡顿时长(ms)']
v_=data['播放阶段平均速率(kbps)']
v_max=data[]
eta=data['卡顿占比']
m=data['卡顿次数']
mu=data['视频码率(kbps)']

# %%
def t_s_model(m,mu,v_):
    Dr=(m*2.7*mu)
    return 1000*Dr/v_

# %%
t_s_expect=t_s_model(m,mu,v_)
t_s_expect.name='预期卡顿时间(ms)'

# %%
t_s_compare=pd.DataFrame(data=[t_s_expect,t_s]).T
t_s_compare.head()
# Out:
#        预期卡顿时间(ms)  卡顿时长(ms)
# 138  23853.012781   17265.0
# 206   1370.328542     725.0
# 249   1154.019435    4354.0
# 262   5102.608696    6901.0
# 501   1251.692750     858.0

# %%
# %matplotlib inline  
x=t_s_compare.iloc[:,0]
y=t_s_compare.iloc[:,1]
plt.clf()
g2=plt.figure()
plt.scatter(x,y,color='orange')
plt.xlabel(x.name)
plt.ylabel(y.name)
g2.dpi=140

# %% [markdown]
# 由上图可以看到，存在两个异常数据点。
# 这可能是未对数据进行清洗所致。

# %%
t_s_compare=t_s_compare[t_s_compare.iloc[:,0]<100000]

# %%
t_s_compare.corr()
# Out:
#             预期卡顿时间(ms)  卡顿时长(ms)
# 预期卡顿时间(ms)      1.0000    0.9303
# 卡顿时长(ms)        0.9303    1.0000

# %%
x=t_s_compare.iloc[:,0]
y=t_s_compare.iloc[:,1]
plt.clf()
g2=plt.figure()
plt.scatter(x,y,color='orange')
plt.xlabel(x.name)
plt.ylabel(y.name)
g2.dpi=140

# %% [raw]
# 如图，显然，卡顿时间被严重高估，出现之一情况的原因是建模时未考虑到卡顿后缓冲阶段的速度相对较高。

# %%
def tau_model(tup,n):
    D_0,v_max,RTT,MSS=tup
    Ds=2*(RTT/1000*v_max-MSS)
    s=np.log2((RTT/1000)*v_max/MSS)
    return (D_0-Ds)/(0.75*v_max)*1000+(n+s)*RTT #ms

# %%
def t_s_model_():
